# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/talalnoor/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# My lane is Search Ranking Optimization.
#
# The ML task type is Ranking.
#
# The goal is to build a system that can rank search results according to their relevance for a user's query. The model receives a query and multiple candidate documents/items and predicts which results should appear higher.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# The target is the relevance of a search result for a user query.
#
# Since true relevance is difficult to measure, we use proxy signals:
#
# - User clicks
# - Click-through rate
# - Time spent on results
# - User engagement
#
# The model learns which results are more useful for users.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# The success metric for this ranking problem is NDCG@10.
#
# Other ranking metrics include:
# - MAP
# - MRR
#
# NDCG@10 measures whether the most relevant results appear in the top search positions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

data = {
    "query": ["python course", "python course", "best laptop"],
    "document": [
        "Python beginner tutorial",
        "Advanced Python book",
        "Laptop buying guide"
    ],
    "clicks": [200, 50, 150],
    "relevance_score": [3, 1, 3]
}

df = pd.DataFrame(data)

df
# Out:
#            query                  document  clicks  relevance_score
# 0  python course  Python beginner tutorial     200                3
# 1  python course      Advanced Python book      50                1
# 2    best laptop       Laptop buying guide     150                3

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# One row represents one query-document pair.
#
# Each row contains:
# - user query
# - search result/document
# - interaction data
# - relevance score
#
# The model learns which documents should rank higher.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# A fixed rule system uses simple conditions like keyword matching or popularity.
#
# However, users have different search intentions and simple rules cannot understand complex patterns.
#
# Machine learning can learn from user behavior, previous searches, and document features to create better rankings.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %% [markdown]
# ✓ Task type: Ranking
#
# ✓ Target/proxy: User clicks, engagement signals, and relevance score
#
# ✓ Success metric: NDCG@10
#
# ✓ Unit of analysis: Query-document pair
#
# ✓ Output action: Show the most relevant search results first
#
# ✓ Why ML: ML learns patterns that fixed rules cannot capture.
